# %%
import pandas as pd 

# separation du texte en phrase 
from nltk.tokenize import PunktSentenceTokenizer 
#import nltk

# separation du texte en mot 
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

#Word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

#from sklearn.feature_extraction.text import CountVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # separation du texte en phrase
# ----> 4 from nltk.tokenize import PunktSentenceTokenizer
#       5 #import nltk
#       6
#       7 # separation du texte en mot
#       8 from nltk.tokenize import sent_tokenize, word_tokenize
#
# ModuleNotFoundError: No module named 'nltk'

# %%
#import des fichiers scrappés
df_Giantbomb=pd.read_csv("./DataFrame/Scrapping/Giantbomb_scrapping_reviews.csv",names=["Name","Reviews"])
df_Metactritic=pd.read_excel("./DataFrame/Scrapping/Metacritic_Assassins_Creed_comments.xlsx",usecols=[3,4],names=["Reviews","Name"])
df_Giantbomb.Name=df_Giantbomb.Name.replace("Assassin'creed","Assassin's Creed")

#fusion des deux fichiers
df_Giant_Meta=pd.concat([df_Giantbomb,df_Metactritic])
df_Giant_Meta.to_excel("./DataFrame/Scrapping/Fichier_scrapping_fusionne.xlsx")

#valeurs à remplacer
dict_nettoyage={"...\n":".","NaN\n":"","NaN":''}

#séparation des dataframe
df_Assassin_s_Creed=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_II=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed II"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Brotherhood=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed: Brotherhood"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_III=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed III"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_IV_Black_Flag=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed IV: Black Flag"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Rogue=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed: Rogue"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Unity=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed Unity"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Syndicate=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed Syndicate"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Origins=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed Origins"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Odyssey=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed Odyssey"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Valhalla=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed Valhalla"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Revelations=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed: Revelations"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')
df_Assassin_s_Creed_Rogue=df_Giant_Meta.Reviews[df_Giant_Meta["Name"]=="Assassin's Creed Rogue"].to_string(index = False).replace("...\n",".").replace("NaN\n","").replace("NaN",'')

# %%
len(df_Metactritic)
# Out:
# 12930

# %%
# separation des commentaires en Phrases 

tokenizer = PunktSentenceTokenizer()
sentance=tokenizer.tokenize(df_Assassin_s_Creed_Rogue)
sentance
# Out:
# ["Shay is awesome, the game is awesome and harder.Assassin's Creed Rogue is perhaps the best Assa.Assassins Creed Rogue is the ending of the kenw.This game was really fun.",
#  "Lots of the good part.I found this game to be much more entertaining .When you first open the menu of ACRoguge, you'r.I am a big fan when it comes to open world adve.The last AAA game made specifically for the las.It's amazing that all these years I was under t.Rogue is very much like Black Black and plays e.What do you get when mixing the best elements f.Assassin's Creed Rogue concludes the Colonial E.Taking place before the events of AC3 and AC Un.Wow, this is much better than Unity !",
#  '!',
#  'The game.',
#  ', click expand to view\nThe gameplay is virtually the same as AC4 and m.Thank you, Ubisoft Sofia!',
# ...

# %%
mots=nltk.tokenize.word_tokenize(df_Assassin_s_Creed_Rogue, language='english', preserve_line=False)

stop_words = set(stopwords.words('english'))
# ajouter les mots vides : "." et ","
mots_vides = [",",".",'is',"game","assassin",'assassin','creed','Creed','Rogue',"''s"]
stop_words.update(mots_vides)

token=[]
for i in mots:
    if i in stop_words:
        #print("in")
        token.append(i)
    else:
        pass
        #print("not in")


vectorizer = CountVectorizer()
vectorizer.fit_transform(token)
tokenized = vectorizer.vocabulary_

tokenized=dict(sorted(tokenized.items(),key=lambda x:x[1],reverse=True))

#plt.bar(tokenized.keys(),tokenized.values(),)

# %%
tokenized[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 tokenized[3]
#
# KeyError: 3

# %%
#Word cloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

wc = WordCloud(background_color="black", max_words=100, stopwords=stop_words, max_font_size=50, random_state=42)
plt.figure(figsize= (10,6)) # Initialisation d'une figure
wc.generate(df_Assassin_s_Creed_Rogue)           # "Calcul" du wordcloud
plt.imshow(wc) # Affichage
plt.show()
